# %% [markdown]
# Programming Exam: Use the cashier's algorithm. Develop a program that randomly selects a total charge. Then randomly select a payment in dollars and cents that exceeds that charge. Then have the program calculate the change in pennies, nickels, dimes, quarters, ones, fives, and twenties. Bonus points for anyone who writes a program that can "Count change back."

# %%
import random

total_charge_dollars = random.randint(1,100)
#print(f"The total dollars are: {total_charge_dollars}")
total_charge_cents = random.randint(1,100)
#print(f"The total cents are: {total_charge_cents}")
total_change = float(str(total_charge_dollars) + "." + str(total_charge_cents))
#print(total_change_float)
print(f"The total change is ${total_change}.")

user_payment = 105
user_payment_formated = "{:.2f}".format(user_payment)
print(f"The user paid :${user_payment_formated}")

customer_change = user_payment - total_change
print(f"The user should get back ${customer_change}")

working_change_value = customer_change
#100 dollar bills
if 100 <= working_change_value:
    print("You can give back a hundred dollars.")
    working_change_value = working_change_value - 100.0
    print(f"You still owe the customer :$ {working_change_value}.")

if 50 <= working_change_value:
    print("You can give back 50 dollars.")
    working_change_value = working_change_value - 50.0
    print(f"You still owe the customer :$ {working_change_value}.")

if 20 <= working_change_value:
    print("You can give back 20 dollars.")
    working_change_value = working_change_value - 20.0
    print(f"You still owe the customer :$ {working_change_value}.")
if 20 <= working_change_value:
    print("You can give back 20 dollars.")
    working_change_value = working_change_value - 20.0
    print(f"You still owe the customer :$ {working_change_value}.")
    
if 10 <= working_change_value:
    print("You can give back 10 dollars.")
    working_change_value = working_change_value - 10.0
    print(f"You still owe the customer :$ {working_change_value}.")

if 5 <= working_change_value:
    print("You can give back 5 dollars.")
    working_change_value = working_change_value - 5.0
    print(f"You still owe the customer :$ {working_change_value}.")
    
if 1 <= working_change_value:
    print("You can give back 1 dollars.")
    working_change_value = working_change_value - 1.0
    print(f"You still owe the customer :$ {working_change_value}.")
if 1 <= working_change_value:
    print("You can give back 1 dollars.")
    working_change_value = working_change_value - 1.0
    print(f"You still owe the customer :$ {working_change_value}.")
if 1 <= working_change_value:
    print("You can give back 1 dollars.")
    working_change_value = working_change_value - 1.0
    print(f"You still owe the customer :$ {working_change_value}.")
if 1 <= working_change_value:
    print("You can give back 1 dollars.")
    working_change_value = working_change_value - 1.0
    print(f"You still owe the customer :$ {working_change_value}.")

if 0.25 <= working_change_value:
    print("You can give back a quarter.")
    working_change_value = working_change_value - 0.25
    print(f"You still owe the customer :$ {working_change_value}.")
if 0.25 <= working_change_value:
    print("You can give back a quarter.")
    working_change_value = working_change_value - 0.25
    print(f"You still owe the customer :$ {working_change_value}.")
if 0.25 <= working_change_value:
    print("You can give back a quarter.")
    working_change_value = working_change_value - 0.25
    print(f"You still owe the customer :$ {working_change_value}.")

if 0.10 <= working_change_value:
    print("You can give back a dime.")
    working_change_value = working_change_value - 0.10
    print(f"You still owe the customer :$ {working_change_value}.")
if 0.10 <= working_change_value:
    print("You can give back a dime.")
    working_change_value = working_change_value - 0.10
    print(f"You still owe the customer :$ {working_change_value}.")

if 0.05 <= working_change_value:
    print("You can give back a nickel.")
    working_change_value = working_change_value - 0.05
    print(f"You still owe the customer :$ {working_change_value}.")

if 0.01 <= working_change_value:
    print("You can give back a penny.")
    working_change_value = working_change_value - 0.01
    print(f"You still owe the customer :$ {working_change_value}.")
if 0.01 <= working_change_value:
    print("You can give back a penny.")
    working_change_value = working_change_value - 0.01
    print(f"You still owe the customer :$ {working_change_value}.")
if 0.01 <= working_change_value:
    print("You can give back a penny.")
    working_change_value = working_change_value - 0.01
    print(f"You still owe the customer :$ {working_change_value}.")
if 0.01 <= working_change_value:
    print("You can give back a penny.")
    working_change_value = working_change_value - 0.01
    print(f"You still owe the customer :$ {working_change_value}.")
# Out:
# The total change is $70.29.
# The user paid :$105.00
# The user should get back $34.709999999999994
# You can give back 20 dollars.
# You still owe the customer :$ 14.709999999999994.
# You can give back 10 dollars.
# You still owe the customer :$ 4.709999999999994.
# You can give back 1 dollars.
# You still owe the customer :$ 3.7099999999999937.
# You can give back 1 dollars.
# You still owe the customer :$ 2.7099999999999937.
# You can give back 1 dollars.
# You still owe the customer :$ 1.7099999999999937.
# You can give back 1 dollars.
# You still owe the customer :$ 0.7099999999999937.
# You can give back a quarter.
# You still owe the customer :$ 0.45999999999999375.
# You can give back a quarter.
# You still owe the customer :$ 0.20999999999999375.
# You can give back a dime.
# You still owe the customer :$ 0.10999999999999374.
# You can give back a dime.
# You still owe the customer :$ 0.009999999999993736.
